# %%
from numpy import nan
from numpy import isnan
from pandas import read_csv
from pandas import to_numeric
import pandas as pd

# %%
import pathlib

# %%
#header_list=["Fecha",'Ind. General', 'Ind. Subyacente', 'Ind. No Subyacente']
trainset = pd.read_csv("./../data/trainset.csv")

trainset.plot(x="Fecha", figsize=(12, 7))

testset = pd.read_csv("./../data/testset.csv")
testset.plot(x="Fecha", figsize=(12, 7))

dataset = pd.concat([trainset,testset])
dataset.plot(x="Fecha", figsize=(12, 7))

#print(inflation)
#dataset.plot()
#dataset = dataset.astype('float32')
# Out:
# <AxesSubplot:xlabel='Fecha'>

# %%
def MAE(x, y):
    length = len(x)
    assert length  == len(y), "Predictions list and Target list must have the same lenght"
    result = 0
    for i in range(length):
        result += x[i] - y[i]
    return result / length

# %%
def evaluate_model(train,test,prediction):
    first = 0.3*((1/2)*MAE(train['General'],prediction['General'])+(1/2)*MAE(train['Subyacente'],prediction['General']))
    second = 0.7*((1/2)*MAE(test['General'],prediction['General'])+(1/2)*MAE(train['Subyacente'],prediction['General']))
    return first+second

# %%
evaluate_model(train=trainset,test=testset,prediction=dataset)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-f7c4411844d1> in <module>
# ----> 1 evaluate_model(train=trainset,test=testset,prediction=dataset)
#
# <ipython-input-11-0d6e74c41160> in evaluate_model(train, test, prediction)
#       8
#       9 def evaluate_model(train,test,prediction):
# ---> 10     first = 0.3*((1/2)*MAE(train['General'],prediction['General'])+(1/2)*MAE(train['Subyacente'],prediction['General']))
#      11     second = 0.7*((1/2)*MAE(test['General'],prediction['General'])+(1/2)*MAE(train['Subyacente'],prediction['General']))
#
# <ipython-input-11-0d6e74c41160> in MAE(x, y)
#       1 def MAE(x, y):
#       2     length = len(x)
# ----> 3     assert length  == len(y), "Predictions list and Target list must have the same lenght"
#       4     result = 0
#       5     for i in range(length):
#
# ...
